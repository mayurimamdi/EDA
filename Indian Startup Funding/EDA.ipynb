# %%
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt 
import numpy as np

# %%
df = pd.read_csv("/Users/mayurimamdi/Downloads/startup_funding.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3044 entries, 0 to 3043
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Sr No              3044 non-null   int64
#  1   Date dd/mm/yyyy    3044 non-null   object
#  2   Startup Name       3044 non-null   object
#  3   Industry Vertical  2873 non-null   object
#  4   SubVertical        2108 non-null   object
#  5   City  Location     2864 non-null   object
#  6   Investors Name     3020 non-null   object
#  7   InvestmentnType    3040 non-null   object
#  8   Amount in USD      2084 non-null   object
#  9   Remarks            419 non-null    object
# dtypes: int64(1), object(9)
# memory usage: 237.9+ KB

# %%
df.shape
# Out:
# (3044, 10)

# %%
df.describe()
# Out:
#              Sr No
# count  3044.000000
# mean   1522.500000
# std     878.871435
# min       1.000000
# 25%     761.750000
# 50%    1522.500000
# 75%    2283.250000
# max    3044.000000

# %%
df.describe().T
# Out:
#         count    mean         std  min     25%     50%      75%     max
# Sr No  3044.0  1522.5  878.871435  1.0  761.75  1522.5  2283.25  3044.0

# %%
df.head()
# Out:
#    Sr No Date dd/mm/yyyy                  Startup Name    Industry Vertical  \
# 0      1      09/01/2020                        BYJU’S               E-Tech
# 1      2      13/01/2020                        Shuttl       Transportation
# 2      3      09/01/2020                     Mamaearth           E-commerce
# 3      4      02/01/2020  https://www.wealthbucket.in/              FinTech
# 4      5      02/01/2020                        Fashor  Fashion and Apparel
#
#                              SubVertical City  Location  \
# 0                             E-learning      Bengaluru
# 1              App based shuttle service        Gurgaon
# 2  Retailer of baby and toddler products      Bengaluru
# 3                      Online Investment      New Delhi
# 4            Embroiled Clothes For Women         Mumbai
#
#               Investors Name       InvestmentnType Amount in USD Remarks
# 0    Tiger Global Management  Private Equity Round  20,00,00,000     NaN
# ...

# %%
df.tail()
# Out:
#       Sr No Date dd/mm/yyyy      Startup Name Industry Vertical SubVertical  \
# 3039   3040      29/01/2015        Printvenue               NaN         NaN
# 3040   3041      29/01/2015          Graphene               NaN         NaN
# 3041   3042      30/01/2015    Mad Street Den               NaN         NaN
# 3042   3043      30/01/2015         Simplotel               NaN         NaN
# 3043   3044      31/01/2015  couponmachine.in               NaN         NaN
#
#      City  Location                     Investors Name InvestmentnType  \
# 3039            NaN        Asia Pacific Internet Group  Private Equity
# 3040            NaN                     KARSEMVEN Fund  Private Equity
# 3041            NaN     Exfinity Fund, GrowX Ventures.  Private Equity
# 3042            NaN                         MakeMyTrip  Private Equity
# 3043            NaN  UK based Group of Angel Investors    Seed Funding
#
#      Amount in USD                            Remarks
# ...

# %%
df.isnull().sum()
# Out:
# Sr No                   0
# Date dd/mm/yyyy         0
# Startup Name            0
# Industry Vertical     171
# SubVertical           936
# City  Location        180
# Investors Name         24
# InvestmentnType         4
# Amount in USD         960
# Remarks              2625
# dtype: int64

# %%
df['Remarks'].value_counts()
# Out:
# Remarks
# Series A                             175
# Series B                              63
# Pre-Series A                          37
# Series C                              28
# Series D                              11
#                                     ...
# Pre Series-A                           1
# QPrize Contest Winners                 1
# pre-series A                           1
# Personal Investment                    1
# Strategic Funding, Minority stake      1
# Name: count, Length: 72, dtype: int64

# %%
df.drop('Remarks', axis=1, inplace=True)

# %%
df.isnull().sum()
# Out:
# Sr No                  0
# Date dd/mm/yyyy        0
# Startup Name           0
# Industry Vertical    171
# SubVertical          936
# City  Location       180
# Investors Name        24
# InvestmentnType        4
# Amount in USD        960
# dtype: int64

# %%
df['Industry Vertical'].fillna('Unknown', inplace=True)
# Out:
# /var/folders/ph/wg0wr1gs4qs24s_3z3tp0pj80000gn/T/ipykernel_9365/1958714157.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Industry Vertical'].fillna('Unknown', inplace=True)

# %%
df['SubVertical'].fillna('Unknown', inplace=True)
# Out:
# /var/folders/ph/wg0wr1gs4qs24s_3z3tp0pj80000gn/T/ipykernel_9365/1436837685.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['SubVertical'].fillna('Unknown', inplace=True)

# %%
df['City  Location'].fillna('Unknown', inplace=True)
# Out:
# /var/folders/ph/wg0wr1gs4qs24s_3z3tp0pj80000gn/T/ipykernel_9365/3593335569.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['City  Location'].fillna('Unknown', inplace=True)

# %%
df['Investors Name'].fillna('Unknown', inplace=True)
# Out:
# /var/folders/ph/wg0wr1gs4qs24s_3z3tp0pj80000gn/T/ipykernel_9365/2063111835.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Investors Name'].fillna('Unknown', inplace=True)

# %%
df['InvestmentnType'].fillna('Unknown', inplace=True)
# Out:
# /var/folders/ph/wg0wr1gs4qs24s_3z3tp0pj80000gn/T/ipykernel_9365/2745005159.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['InvestmentnType'].fillna('Unknown', inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.groupby('Startup Name')['Startup Name'].count().sort_values(ascending=False).head(10)
# Out:
# Startup Name
# Ola Cabs         8
# Swiggy           8
# Paytm            7
# NoBroker         6
# Meesho           6
# Medinfi          6
# UrbanClap        6
# Nykaa            6
# Uniphore         5
# Capital Float    5
# Name: Startup Name, dtype: int64

# %%
df
# Out:
#       Sr No Date dd/mm/yyyy                  Startup Name  \
# 0         1      09/01/2020                        BYJU’S
# 1         2      13/01/2020                        Shuttl
# 2         3      09/01/2020                     Mamaearth
# 3         4      02/01/2020  https://www.wealthbucket.in/
# 4         5      02/01/2020                        Fashor
# ...     ...             ...                           ...
# 3039   3040      29/01/2015                    Printvenue
# 3040   3041      29/01/2015                      Graphene
# 3041   3042      30/01/2015                Mad Street Den
# 3042   3043      30/01/2015                     Simplotel
# 3043   3044      31/01/2015              couponmachine.in
#
#         Industry Vertical                            SubVertical  \
# 0                  E-Tech                             E-learning
# 1          Transportation              App based shuttle service
# 2              E-commerce  Retailer of baby and toddler products
# ...

# %%
#df['year'] = df['Date dd/mm/yyyy'].str.split('/').str[2]
df['year'] = df['Date dd/mm/yyyy'].str.extract(r'(\d{4})$')

# %%
df.groupby('year')['Startup Name'].count().sort_values(ascending=False)
# Out:
# year
# 2016    993
# 2015    935
# 2017    687
# 2018    310
# 2019    111
# 2020      7
# Name: Startup Name, dtype: int64

# %%
df[df['Date dd/mm/yyyy'] == '22/01//2015'] = df[df['Date dd/mm/yyyy'] == '22/01//2015'].map(lambda x: '22/01/2015' if x == '22/01//2015' else x)

# %%
#df['year'] = df['Date dd/mm/yyyy'].str.split('/').str[2]

# %%
df[df['Sr No'] == 3030]
# Out:
#       Sr No Date dd/mm/yyyy  Startup Name Industry Vertical SubVertical  \
# 3029   3030      22/01/2015  Corporate360           Unknown     Unknown
#
#      City  Location            Investors Name InvestmentnType Amount in USD  \
# 3029        Unknown  Group of Angel Investors    Seed Funding      2,00,000
#
#       year
# 3029  2015

# %% [markdown]
# It has been fixed now

# %%
df[df['year'].isnull()]
# Out:
#       Sr No Date dd/mm/yyyy Startup Name  \
# 2571   2572       01/07/015    HandyHome
#
#                           Industry Vertical SubVertical City  Location  \
# 2571  Hyperlocal Electronics repair Service     Unknown         Mumbai
#
#                       Investors Name InvestmentnType Amount in USD year
# 2571  Bessemer Ventures, Kae Capital    Seed Funding      6,30,000  NaN

# %%
df.isnull().sum()
# Out:
# Sr No                  0
# Date dd/mm/yyyy        0
# Startup Name           0
# Industry Vertical      0
# SubVertical            0
# City  Location         0
# Investors Name         0
# InvestmentnType        0
# Amount in USD        960
# year                   1
# dtype: int64

# %%
df['year'] = df['year'].fillna(lambda x: '2015' if x == '015' else x)

# %%
df.isnull().sum()
# Out:
# Sr No                  0
# Date dd/mm/yyyy        0
# Startup Name           0
# Industry Vertical      0
# SubVertical            0
# City  Location         0
# Investors Name         0
# InvestmentnType        0
# Amount in USD        960
# year                   0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Sr No                0
# Date dd/mm/yyyy      0
# Startup Name         0
# Industry Vertical    0
# SubVertical          0
# City  Location       0
# Investors Name       0
# InvestmentnType      0
# Amount in USD        0
# year                 0
# dtype: int64

# %%
df.shape
# Out:
# (2084, 10)

# %% [markdown]
# As amount is important feature if we dont know the actual value then its better to delete it

# %%
plt.figure(figsize=(12,6))
sns.countplot(x='year', data=df)
plt.title('Number of Startups Funded Each Year')
plt.xlabel('Year')
plt.ylabel('Number of Startups')
plt.xticks(rotation=45)
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2084 entries, 0 to 3043
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Sr No              2084 non-null   int64
#  1   Date dd/mm/yyyy    2084 non-null   object
#  2   Startup Name       2084 non-null   object
#  3   Industry Vertical  2084 non-null   object
#  4   SubVertical        2084 non-null   object
#  5   City  Location     2084 non-null   object
#  6   Investors Name     2084 non-null   object
#  7   InvestmentnType    2084 non-null   object
#  8   Amount in USD      2084 non-null   object
#  9   year               2084 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 179.1+ KB

# %%
df[df['year'] == '2015']
# Out:
#       Sr No Date dd/mm/yyyy      Startup Name  \
# 2108   2109      01/12/2015      CollegeDekho
# 2111   2112      01/12/2015   Patel Logistics
# 2112   2113      01/12/2015             Wigzo
# 2114   2115      01/12/2015   Godof Hospitals
# 2115   2116      02/12/2015       RoomsTonite
# ...     ...             ...               ...
# 3038   3039      28/01/2015     Grabhouse.com
# 3039   3040      29/01/2015        Printvenue
# 3040   3041      29/01/2015          Graphene
# 3041   3042      30/01/2015    Mad Street Den
# 3043   3044      31/01/2015  couponmachine.in
#
#                              Industry Vertical SubVertical City  Location  \
# 2108     Online Education Information platform     Unknown         Jaipur
# 2111       Transportation & Logistics Platform     Unknown         Mumbai
# 2112  Enterprise Marketing Automation platform     Unknown      New Delhi
# 2114                        Digital Healthcare     Unknown      New Delhi
# ...

# %%
df_2015 = df[df['year'] == '2015']

# %%
df_2015.head(10)
# Out:
#       Sr No Date dd/mm/yyyy         Startup Name  \
# 2108   2109      01/12/2015         CollegeDekho
# 2111   2112      01/12/2015      Patel Logistics
# 2112   2113      01/12/2015                Wigzo
# 2114   2115      01/12/2015      Godof Hospitals
# 2115   2116      02/12/2015          RoomsTonite
# 2118   2119      03/12/2015           EasyKhaana
# 2119   2120      03/12/2015               Shuttl
# 2122   2123      04/12/2015               Applop
# 2123   2124      04/12/2015                CaRPM
# 2124   2125      04/12/2015  NDTV Wedding portal
#
#                              Industry Vertical SubVertical City  Location  \
# 2108     Online Education Information platform     Unknown         Jaipur
# 2111       Transportation & Logistics Platform     Unknown         Mumbai
# 2112  Enterprise Marketing Automation platform     Unknown      New Delhi
# 2114                        Digital Healthcare     Unknown      New Delhi
# ...

# %%
print(df_2015.shape)
# Out:
# (657, 10)

# %%
top10 = df.sort_values('Amount in USD', ascending=False).head(10)

plt.figure(figsize=(10,6))

sns.barplot(data=top10, x='Amount in USD', y='Startup Name')

plt.title('Top 10 Funded Startups')
plt.show()

# %%
df['SubVertical'].value_counts().head(10)
# Out:
# SubVertical
# Unknown                      658
# Online Lending Platform       11
# Online Pharmacy                5
# Online Lending                 5
# Education                      5
# Online Education Platform      4
# Food Delivery Platform         4
# Online lending platform        4
# Online Learning Platform       4
# Online Food Delivery           4
# Name: count, dtype: int64

# %%
df[df['Amount in USD'] == 'unknown']
# Out:
#     Sr No Date dd/mm/yyyy     Startup Name Industry Vertical  \
# 34     35      21/10/2019  The Man Company    Consumer Goods
#
#             SubVertical City  Location     Investors Name  InvestmentnType  \
# 34  Beauty and Grooming        Gurgaon  Ayushmann Khurana  Corporate Round
#
#    Amount in USD  year
# 34       unknown  2019

# %%
df[df['Amount in USD'] == 'undisclosed']
# Out:
#     Sr No Date dd/mm/yyyy  Startup Name  Industry Vertical  \
# 20     21      17/11/2019  Burger Singh  Food and Beverage
# 89     90      06/05/2019  Ola Electric          Transport
# 91     92      05/05/2019    StyleDotMe         E-commerce
#
#              SubVertical City  Location  \
# 20   Indian Burger Brand        Gurgaon
# 89                  Cabs      Bengaluru
# 91  Fashion and Shopping          Delhi
#
#                                        Investors Name InvestmentnType  \
# 20                                     RB Investments         Venture
# 89                                          Tata Sons        Series A
# 91  Indian Angel Network and other angel investors...    Bridge Round
#
#    Amount in USD  year
# 20   undisclosed  2019
# 89   undisclosed  2019
# 91   undisclosed  2019

# %%
df.drop(df[df['Amount in USD'] == 'undisclosed'].index, inplace=True)

# %%
df.drop(df[df['Amount in USD'] == 'unknown'].index, inplace=True)

# %%
top10 = df.sort_values('Amount in USD', ascending=False).head(10)

plt.figure(figsize=(15,10))

sns.barplot(data=top10, x='Amount in USD', y='Startup Name')

plt.title('Top 10 Funded Startups')
plt.show()

# %%
top_5 = df.groupby('Startup Name')['Amount in USD'].sum().sort_values(ascending=False).head(5)

# %%
top_5
# Out:
# Startup Name
# \\xc2\\xa0Shopsity                    \\xc2\\xa0N/A
# \\xc2\\xa0Satvacart                   \\xc2\\xa0N/A
# \\xc2\\xa0Notesgen                    \\xc2\\xa0N/A
# \\xc2\\xa0Footprints Education    \\xc2\\xa0685,000
# \\xc2\\xa0Infinity Assurance      \\xc2\\xa0600,000
# Name: Amount in USD, dtype: object

# %%
df.groupby('Startup Name')['SubVertical'].count().sort_values(ascending=False).head(10)
plt.figure(figsize=(12,6))
sns.countplot(y='SubVertical', data=df, order=df['SubVertical'].value_counts().index[:10])
plt.title('Top 10 SubVerticals with Most Funded Startups')
plt.xlabel('Number of Startups')
plt.ylabel('SubVertical')
plt.show()
